# %% [markdown]
# # Visualization
#
# ---

# %% [markdown]
# To select the correct chart type is most important.
#
# There are basic presentation types:
#
# * Comparison
#
# * Composition
#
# * Distribution
#
# * Relationship

# %% [markdown]
# #Comparion

# %% [markdown]
# **Matplotlib Bar Chart**
# Inputs
# * x: A sequence of scalars that are the x-coordinates of the bars.
# * height: A sequence of scalars that are the height(s) of the bars.
# * width(Optional): An array containing the width of the bars.
# * bottom(Optional): An array containing the y coordinate(s) of the bases of the bars.
# * align(Optional): Has two possible values, center or edge. These values define whether the bars will center their base on the x-coordinate, or align their left edge with the x-coordinate.

# %%
import matplotlib.pyplot as plt

# %%
data = [23, 45, 56, 78, 21,55]
x = ['Nuclear', 'Hydro', 'Gas', 'Oil', 'Coal', 'Biofuel']
plt.bar(x, data)
plt.show()

# %%
plt.bar(x, data,color='red')
plt.show()

# %%
#having grids
plt.bar(x, data,color='red')
plt.grid(color='black',linestyle='--',linewidth=1, axis='y')
plt.show()

# %%
#having labels
plt.bar(x, data,color='red')
plt.xlabel("Energy")
plt.ylabel("Production")
plt.title("Energy production in India")
# Out:
# Text(0.5, 1.0, 'Energy production in India')

# %% [markdown]
# Horizontal Bar Chart

# %%
plt.barh(x, data,color='purple')
plt.show()

# %%
import numpy as np
i = np.arange(5)
print(i) 
virat=[98,12,45,120,0]
sachin=[12,56,77,99,127]
width=0.35
plt.bar(i,virat,width,label="Virat" )
plt.bar(i+width,sachin,width,label="Sachin")
plt.ylabel("Score")
plt.show()
# Out:
# [0 1 2 3 4]

# %%
plt.bar(i,virat,width,label="Virat" )
plt.bar(i+width,sachin,width,label="Sachin")
plt.ylabel("Score")
plt.xticks(i + width / 2, ('M1', 'M2', 'M3', 'M4', 'M5'))
plt.show()

# %%
plt.bar(i,virat,width,label="Virat" )
plt.bar(i+width,sachin,width,label="Sachin")
plt.ylabel("Score")
plt.xticks(i + width / 2, ('M1', 'M2', 'M3', 'M4', 'M5'))
plt.legend()
plt.show()

# %% [markdown]
#  **Line Plot**

# %%
Year = [1920,1930,1940,1950,1960,1970,1980,1990,2000,2010]
Unemployment_Rate = [9.8,12,8,7.2,6.9,7,6.5,6.2,5.5,6.3]

plt.plot(Year, Unemployment_Rate)

# %%
plt.plot(Year, Unemployment_Rate)
plt.title('Unemployment Rate Vs Year')
plt.xlabel('Year')
plt.ylabel('Unemployment Rate')
plt.show()

# %%
plt.plot(Year, Unemployment_Rate, color='green')

# %% [markdown]
# markers = {'.': 'point', ',': 'pixel', 'o': 'circle', 'v': 'triangle_down', '^': 'triangle_up', '<': 'triangle_left', '>': 'triangle_right', '1': 'tri_down', '2': 'tri_up', '3': 'tri_left', '4': 'tri_right', '8': 'octagon', 's': 'square', 'p': 'pentagon', '*': 'star', 'h': 'hexagon1', 'H': 'hexagon2', '+': 'plus', 'x': 'x', 'D': 'diamond', 'd': 'thin_diamond', '|': 'vline', '_': 'hline', 'P': 'plus_filled', 'X': 'x_filled', 0: 'tickleft', 1: 'tickright', 2: 'tickup', 3: 'tickdown', 4: 'caretleft', 5: 'caretright', 6: 'caretup', 7: 'caretdown', 8: 'caretleftbase', 9: 'caretrightbase', 10: 'caretupbase', 11: 'caretdownbase', 'None': 'nothing', 'none': 'nothing', ' ': 'nothing', '': 'nothing'}

# %%
plt.plot(Year, Unemployment_Rate, color='red', marker='X')
plt.grid(True)

# %%
#multiple lines
education=[.2,1,2.1,7.2,6.9,7.5,7.8,8.0,16.3,25]
plt.plot(Year, Unemployment_Rate, color='red', marker='o')
plt.plot(Year, education, color='green',marker='>')
plt.grid(True)

# %% [markdown]
# **Corelation**
#
# It measures the strength of association between two variables and the direction of the relationship.
#
# **Scatter Plot** is used to see the relationship between
# two continuous variables.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('/content/drive/My Drive/Colab Notebooks/Trees.csv')
df
# Out:
#     Girth  Height  Volume
# 0     8.3      70    10.3
# 1     8.6      65    10.3
# 2     8.8      63    10.2
# 3    10.5      72    16.4
# 4    10.7      81    18.8
# 5    10.8      83    19.7
# 6    11.0      66    15.6
# 7    11.0      75    18.2
# 8    11.1      80    22.6
# 9    11.2      75    19.9
# 10   11.3      79    24.2
# 11   11.4      76    21.0
# 12   11.4      76    21.4
# 13   11.7      69    21.3
# 14   12.0      75    19.1
# 15   12.9      74    22.2
# 16   12.9      85    33.8
# 17   13.3      86    27.4
# 18   13.7      71    25.7
# 19   13.8      64    24.9
# 20   14.0      78    34.5
# 21   14.2      80    31.7
# 22   14.5      74    36.3
# 23   16.0      72    38.3
# 24   16.3      77    42.6
# 25   17.3      81    55.4
# 26   17.5      82    55.7
# 27   17.9      80    58.3
# 28   18.0      80    51.5
# 29   18.0      80    51.0
# 30   20.6      87    77.0

# %%
df.describe()
# Out:
#            Girth     Height     Volume
# count  31.000000  31.000000  31.000000
# mean   13.248387  76.000000  30.170968
# std     3.138139   6.371813  16.437846
# min     8.300000  63.000000  10.200000
# 25%    11.050000  72.000000  19.400000
# 50%    12.900000  76.000000  24.200000
# 75%    15.250000  80.000000  37.300000
# max    20.600000  87.000000  77.000000

# %%
x=df['Height']
y=df['Volume']
plt.scatter(x,y)

# %%
plt.scatter(x,y)
plt.xlabel("Height") 
plt.ylabel("Volume") 
plt.show()

# %%
plt.scatter(x,y,marker="^",color='blue')
plt.xlabel("Height") 
plt.ylabel("Volume") 
plt.show()

# %%
plt.scatter(x,y,marker="^",edgecolors="red")
plt.xlabel("Height") 
plt.ylabel("Volume") 
plt.show()

# %%
plt.scatter(x,y,marker="^",edgecolors="red",linewidths = 2)
plt.xlabel("Height") 
plt.ylabel("Volume") 
plt.show()

# %%
plt.scatter(x,y,marker="^",edgecolors="red",linewidths = 2,s=100)
plt.xlabel("Height") 
plt.ylabel("Volume") 
plt.show()

# %%
plt.scatter(x,y,marker="^",edgecolors="red",linewidths = 2,s=100,c="pink")
plt.xlabel("Height") 
plt.ylabel("Volume") 
plt.show()

# %%
x=df['Girth']
y=df['Volume']
plt.scatter(x,y,marker="^",edgecolors="red",linewidths = 2,s=100,c="pink")
plt.xlabel("Girth") 
plt.ylabel("Volume") 
plt.show()

# %% [markdown]
# how to save the plot
#
# savefig() is used to save the plot
# dpi can be used to set the resolution of the file to a numeric value.
#
# transparent can be set to True, which causes the background of the chart to be transparent.
#
# bbox_inches can be set to alter the size of the bounding box (whitespace) around the output image. In most cases, if no bounding box is desired, using bbox_inches='tight' is ideal.
#
# If bbox_inches is set to 'tight', then the pad_inches option specifies the amount of padding around the image.

# %%
plt.savefig("cor.png")

# %%
import seaborn as sns
iris = sns.load_dataset("iris")
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
plt.scatter(iris['sepal_length'],iris['species'],marker="<",edgecolors="red",linewidths = 2,s=100,c="pink")
plt.xlabel("sepal length") 
plt.ylabel("species") 
plt.show()

# %%
plt.scatter(iris['sepal_width'],iris['species'],marker="*",edgecolors="red",linewidths = 2,s=100,c="pink")
plt.xlabel("sepal width") 
plt.ylabel("species") 
plt.show()

# %%
plt.scatter(iris['petal_length'],iris['species'],marker="s",edgecolors="red",linewidths = 2,s=100,c="pink")
plt.xlabel("Petal_length") 
plt.ylabel("Species") 
plt.show()

# %% [markdown]
# # Scatterplot with seaborn library

# %%
import seaborn as sns
sns.scatterplot(x=iris['petal_length'],y=iris['petal_width'])

# %% [markdown]
# The hue parameter can be used to group the multiple data variables and show dependency between them in terms of different colors of the markers used to plot the data values.
#
# hue: The data parameter around which the dependency of the passed data values are to be plotted.

# %%
sns.scatterplot(x=iris['petal_length'],y=iris['petal_width'],hue=iris["species"])

# %% [markdown]
# Using style as a parameter, we can depict the relationship between multiple data variables and their dependency using different types of scatter icons used to depict the data values.
#
# Syntax: seaborn.scatterplot(x,y,data,style)
#
# style: The data parameter which acts as a reference to plot the multivariable relationship.

# %%
sns.scatterplot(x=iris['petal_length'],y=iris['petal_width'],style=iris["species"])

# %% [markdown]
# How to see the entire picture
#
# sns pairplot

# %%
sns.pairplot(iris)

# %%
#If you prefer a smaller plot, use less variables. For instance, if you only want sepal_width and sepal_length, tha would create a 2x2 plot.
sns.pairplot(iris, vars=["sepal_width", "sepal_length"])

# %% [markdown]
# diag_kind{‘auto’, ‘hist’, ‘kde’, None}
#
# Kind of plot for the diagonal subplots.
#
# kde = Kernel Density estimation
#
# If ‘auto’, choose based on whether or not hue is used.

# %%
sns.pairplot(iris, diag_kind="kde")

# %% [markdown]
# The hue parameter can be used to group the multiple data variables and show dependency between them in terms of different colors of the markers used to plot the data values.
#
# hue: The data parameter around which the dependency of the passed data values are to be plotted.

# %%
sns.pairplot(iris, hue="species")

# %%
sns.pairplot(iris, height=3, markers=["o", "s", "D"], hue="species")

# %%
df1=pd.read_csv('/content/drive/My Drive/Colab Notebooks/chick.csv')
df1
# Out:
#      weight  Time  Chick  Diet
# 0        42   0.0    1.0   1.0
# 1        51   4.0    1.0   1.0
# 2        59   8.0    1.0   1.0
# 3        64  12.0    1.0   1.0
# 4        76  16.0    1.0   1.0
# ..      ...   ...    ...   ...
# 573     175  28.0   50.0   4.0
# 574     205  32.0   50.0   4.0
# 575     234  36.0   50.0   4.0
# 576     264  40.0   50.0   4.0
# 577     264   NaN    NaN   NaN
#
# [578 rows x 4 columns]

# %%
sns.pairplot(df1)

# %% [markdown]
# Use of scatter plot to guess outlier:
#
# lets insert an outlier in tree dataset

# %%
df

# %%
x=df['Height']
y=df['Volume']
x[0]=210
x
# Out:
# <ipython-input-96-30042dbf6a95>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x[0]=210
# 0     210
# 1      65
# 2      63
# 3      72
# 4      81
# 5      83
# 6      66
# 7      75
# 8      80
# 9      75
# 10     79
# 11     76
# 12     76
# 13     69
# 14     75
# 15     74
# 16     85
# 17     86
# 18     71
# 19     64
# 20     78
# 21     80
# 22     74
# 23     72
# 24     77
# 25     81
# 26     82
# 27     80
# 28     80
# 29     80
# 30     87
# Name: Height, dtype: int64

# %%
plt.scatter(x,y)

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(df1,figsize=(11,9))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f151a3f1eb0>,
# ...
#       dtype=object)

# %% [markdown]
# **Correlation Matrix Plots**

# %%
car = pd.read_csv('https://gist.githubusercontent.com/ZeccaLehn/4e06d2575eb9589dbe8c365d61cb056c/raw/64f1660f38ef523b2a1a13be77b002b98665cdfe/mtcars.csv')
car
# Out:
#              Unnamed: 0   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
# find the corelation
c=car.corr()
print(c)
# Out:
#            mpg       cyl      disp        hp      drat        wt      qsec  \
# mpg   1.000000 -0.852162 -0.847551 -0.776168  0.681172 -0.867659  0.418684
# cyl  -0.852162  1.000000  0.902033  0.832447 -0.699938  0.782496 -0.591242
# disp -0.847551  0.902033  1.000000  0.790949 -0.710214  0.887980 -0.433698
# hp   -0.776168  0.832447  0.790949  1.000000 -0.448759  0.658748 -0.708223
# drat  0.681172 -0.699938 -0.710214 -0.448759  1.000000 -0.712441  0.091205
# wt   -0.867659  0.782496  0.887980  0.658748 -0.712441  1.000000 -0.174716
# qsec  0.418684 -0.591242 -0.433698 -0.708223  0.091205 -0.174716  1.000000
# vs    0.664039 -0.810812 -0.710416 -0.723097  0.440278 -0.554916  0.744535
# am    0.599832 -0.522607 -0.591227 -0.243204  0.712711 -0.692495 -0.229861
# gear  0.480285 -0.492687 -0.555569 -0.125704  0.699610 -0.583287 -0.212682
# carb -0.550925  0.526988  0.394977  0.749812 -0.090790  0.427606 -0.656249
#
#             vs        am      gear      carb
# ...

# %%
sns.heatmap(c)

# %%
plt.subplots(figsize=(10,10))
sns.heatmap(c)

# %%
plt.subplots(figsize=(11,11))
sns.heatmap(c,annot=True)

# %%
plt.subplots(figsize=(11,11))
sns.heatmap(c,annot=True, cmap ="YlGnBu")

# %%
plt.subplots(figsize=(11,11))
sns.heatmap(c,annot=True, cmap ="YlGnBu",linewidths=0.1)

# %% [markdown]
# #Composition

# %% [markdown]
# **Pie Charts**
#
# Syntax: matplotlib.pyplot.pie(data, explode=None, labels=None, colors=None, autopct=None, shadow=False)
#
# Parameters:
# * data represents the array of data values to be plotted, the fractional area of each slice is represented by data/sum(data). If sum(data)<1, then the data values returns the fractional area directly, thus resulting pie will have empty wedge of size 1-sum(data).
# * labels is a list of sequence of strings which sets the label of each wedge.
# * color attribute is used to provide color to the wedges.
# * autopct is a string used to label the wedge with their numerical value.
# * shadow is used to create shadow of wedge.

# %%
cars = ['AUDI', 'BMW', 'FORD', 'TESLA', 'JAGUAR', 'MERCEDES'] 
data = [23, 57, 35, 29, 42, 41] 

plt.pie(data,labels=cars)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f8fba6d5a30>,
# ...
#  [Text(1.0447418523280687, 0.34425929470983924, 'AUDI'),
#   Text(0.1592855985458318, 1.0884062192471597, 'BMW'),
#   Text(-0.9938791185832959, 0.4713855085215191, 'FORD'),
#   Text(-0.9938791406504431, -0.471385461994679, 'TESLA'),
#   Text(-0.15928559854583169, -1.0884062192471597, 'JAGUAR'),
#   Text(0.9276169465489412, -0.5912079164517496, 'MERCEDES')])

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# The startangle parameter is defined with an angle in degrees, default angle is 0:

# %%
plt.pie(data,labels=cars,startangle=90)
plt.show()

# %% [markdown]
# The explode parameter, if specified, and not None, must be an array with one value for each wedge.
#
# Each value represents how far from the center each wedge is displayed:

# %%
myexplode = [0.2, 0, 0.5, 0,0,0]
plt.pie(data,labels=cars,startangle=90,explode=myexplode)
plt.show()

# %%
plt.pie(data,labels=cars,startangle=90,explode=myexplode,shadow=True)
plt.show()

# %% [markdown]
# You can use your own color
#
# * 'r' - Red
# * 'g' - Green
# * 'b' - Blue
# * 'c' - Cyan
# * 'm' - Magenta
# * 'y' - Yellow
# * 'k' - Black
# * 'w' - White

# %%
mycolors = ["hotpink","green","brown",  "red", "y","blue"]
plt.pie(data,labels=cars,startangle=90,explode=myexplode,shadow=True,colors=mycolors)
plt.show()

# %%
mycolors = ["hotpink","green","black",  "red", "y","blue"]
plt.pie(data,labels=cars,startangle=90,explode=myexplode,shadow=True,colors=mycolors)
plt.legend(title="different cars",loc='right')
plt.show()

# %%
mycolors = ["hotpink","green","black",  "red", "y","blue"]
plt.pie(data,labels=cars,startangle=90,explode=myexplode,shadow=True,colors=mycolors,autopct='%1.2f%%')
plt.show()

# %% [markdown]
# **Stack bar chart**
#
# A stacked bar chart or  graph is a chart that uses bars to demonstrate comparisons between categories of data, but with ability to impart and compare parts of a whole. Each bar in the chart represents a whole and segments which represent different parts or categories of that whole.

# %%
A = [5., 30., 45., 12.]
B = [5., 25., 50., 20.]

X = range(4)

plt.bar(X, A, color = 'b')
plt.bar(X, B, color = 'r', bottom = A)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

A = np.array([5., 30., 45., 22.])
B = np.array([5., 25., 50., 20.])
C = np.array([1.8,  2.9,  1.121,  1.])
X = np.arange(4)

plt.bar(X, A, color = 'b')
plt.bar(X, B, color = 'g', bottom = A)
plt.bar(X, C, color = 'r', bottom = A + B)

plt.show()

# %%
import plotly.express as px
 
df = px.data.iris()
 
fig = px.bar(df, x="sepal_width", y="sepal_length", color="species")
 
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.bar(df, x="sepal_width", y="sepal_length", color="species",barmode = 'stack',hover_data=['petal_width'])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **Treemap**
#
# Treemaps display hierarchical data as a set of nested rectangles. Each group is represented by a rectangle, which area is proportional to its value. Using color schemes, it is possible to represent several dimensions: groups, subgroups
#
# These are ideal for displaying large amount of hierarchical data.
#
# We can use a treemap when space is a constraint and we have a large amount of hierarchical data to get an overview.
#
# A treemap is a diagram representing hierarchical data in the form of nested rectangles, the area of each corresponding to its numerical value

# %%
import matplotlib.pyplot as plt
#!pip install squarify
import squarify as sq
s = [40, 30, 5, 25]
sq.plot(s)
plt.show()

# %%
#adding labels
label=["Stationary", "Electronics", "Consumable", "Domestic"]
sq.plot(sizes=s, label=label )
# Out:
# <AxesSubplot:>

# %% [markdown]
# You can see that the color scheme of our treemap is different each time we run it. The colors for rectangles are picked randomly. Treemap also gives you the option to mention the colors along with sizes and labels

# %%
color=['red','blue','green','grey']
sq.plot(sizes=s, label=label, color=color)
# Out:
# <AxesSubplot:>

# %%
import pandas as pd
ss=pd.read_csv('/content/drive/My Drive/Colab Notebooks/Superstore.csv',encoding= 'unicode_escape')
ss
# Out:
#       Row ID        Order ID Order Date Ship Date       Ship Mode Customer ID  \
# 0          1  CA-2016-152156   08-11-16  11-11-16    Second Class    CG-12520
# 1          2  CA-2016-152156   08-11-16  11-11-16    Second Class    CG-12520
# 2          3  CA-2016-138688   12-06-16  16-06-16    Second Class    DV-13045
# 3          4  US-2015-108966   11-10-15  18-10-15  Standard Class    SO-20335
# 4          5  US-2015-108966   11-10-15  18-10-15  Standard Class    SO-20335
# ...      ...             ...        ...       ...             ...         ...
# 9989    9990  CA-2014-110422   21-01-14  23-01-14    Second Class    TB-21400
# 9990    9991  CA-2017-121258   26-02-17  03-03-17  Standard Class    DB-13060
# 9991    9992  CA-2017-121258   26-02-17  03-03-17  Standard Class    DB-13060
# 9992    9993  CA-2017-121258   26-02-17  03-03-17  Standard Class    DB-13060
# 9993    9994  CA-2017-119914   04-05-17  09-05-17    Second Class    CC-12220
#
# ...

# %%
siz=ss.groupby('Category')[['Sales']].sum()

siz
# Out:
#                        Sales
# Category
# Furniture        741999.7953
# Office Supplies  719047.0320
# Technology       836154.0330

# %%
type(siz)
# Out:
# pandas.core.frame.DataFrame

# %%
siz=ss.groupby('Category')[['Sales']].sum().reset_index().Sales.values.tolist()
siz
# Out:
# [741999.7953, 719047.032, 836154.033]

# %%
lab=ss.groupby('Category')[['Sales']].sum().index.get_level_values(0).tolist()
lab
# Out:
# ['Furniture', 'Office Supplies', 'Technology']

# %%
sq.plot(sizes=siz,label=lab)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #Distribution
# An important concept in statistics and data science is distribution. Distribution generally refers to the probability of occurrence of an outcome.

# %% [markdown]
# **Histograms**
#
# To create a histogram the first step is to create bin of the ranges, then distribute the whole range of the values into a series of intervals, and the count the values which fall into each of the intervals.Bins are clearly identified as consecutive, non-overlapping intervals of variables.The matplotlib.pyplot.hist() function is used to compute and create histogram of x.

# %% [markdown]
# Parameters
#
# * x	array or sequence of array
# * bins	optional parameter contains integer or sequence or strings
# * density	optional parameter contains boolean values
# range	optional parameter represents upper and lower range of bins
# * histtype	optional parameter used to creae type of histogram [bar, barstacked, step, stepfilled], default is “bar”
# * align	optional parameter controls the plotting of histogram [left, right, mid]
# * weights	optional parameter contains array of weights having same dimensions as x
# * bottom	location of the basline of each bin
# rwidth	optional parameter which is relative width of the bars with respect to bin width
# * color	optional parameter used to set color or sequence of color specs
# * label	optional parameter string or sequence of string to match with multiple datasets
# * log	optional parameter used to set histogram axis on log scale

# %%
x = [1,1,2,3,3,5,7,8,9,10,
     10,11,11,13,13,15,16,17,18,18,
     18,19,20,21,21,23,24,24,25,25,
     25,25,26,26,26,27,27,27,27,27,
     29,30,30,31,33,34,34,34,35,36,
     36,37,37,38,38,39,40,41,41,42,
     43,44,45,45,46,47,48,48,49,50,
     51,52,53,54,55,55,56,57,58,60,
     61,63,64,65,66,68,70,71,72,74,
     75,77,81,83,84,87,89,90,90,91
     ]

plt.hist(x, bins=10)
plt.show()

# %% [markdown]
# ust by looking at the histogram, you may have noticed the positive Skewness.
#
# You can derive the skew in Python by using the scipy library.

# %%
from scipy.stats import skew
print (skew(x))
# Out:
# 0.4575278444409153

# %% [markdown]
# to determine the number of bins
#
# you can use following formulas:
#
# n = number of observations
#
# Range = maximum value – minimum value
#
# '#' of intervals =  √n
#
# Width of intervals =  Range / (# of intervals)

# %% [markdown]
# Or alternatively one can use the auto feature

# %%
plt.hist(x, bins='auto')
plt.show()

# %% [markdown]
# * histtype='stepfilled'
# *  histtype='step'
# * histtype='barstacked
# * histtype='bar'

# %%
plt.hist(x, bins=10,   histtype='step', color='blue')
# Out:
# (array([ 9., 12., 19., 11., 13., 10.,  8.,  7.,  4.,  7.]),
#  array([ 1., 10., 19., 28., 37., 46., 55., 64., 73., 82., 91.]),
#  [<matplotlib.patches.Polygon at 0x7f8fba6253d0>])

# %% [markdown]
# **Histogram using plotly**

# %%
import plotly.express as px
df = px.data.election()
df
#df.to_csv("medals_long.csv")
# Out:
#                                              district  Coderre  Bergeron  \
# 0                                  101-Bois-de-Liesse     2481      1829
# 1                               102-Cap-Saint-Jacques     2525      1163
# 2                                11-Sault-au-Récollet     3348      2770
# 3                                        111-Mile-End     1734      4782
# 4                                      112-DeLorimier     1770      5933
# 5                                    113-Jeanne-Mance     1455      3599
# 6                                    12-Saint-Sulpice     3252      2521
# 7                          121-La Pointe-aux-Prairies     5456      1760
# 8                             122-Pointe-aux-Trembles     4734      1879
# 9                            123-Rivière-des-Prairies     5737       958
# 10                                        13-Ahuntsic     2979      3430
# 11                                  131-Saint-Édouard     1827      6408
# ...

# %%
import plotly.express as px
df = px.data.tips()
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
fig = px.histogram(df, x="total_bill")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.histogram(df, x="day")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# choosing number of bins
fig = px.histogram(df, x="total_bill", nbins=20)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Type of normalization
#
# The default mode is to represent the count of samples in each bin. With the histnorm argument, it is also possible to represent the percentage or fraction of samples in each bin (histnorm='percent' or probability), or a density histogram (the sum of all bar areas equals the total number of sample points, density), or a probability density histogram (the sum of all bar areas equals 1, probability density).

# %%
fig = px.histogram(df, x="total_bill", histnorm='probability density')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.histogram(df, x="total_bill", color="sex")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Using histfunc
#
# For each bin of x, one can compute a function of data using histfunc. The argument of histfunc is the dataframe column given as the y argument. Below the plot shows that the average tip increases with the total bill.

# %%
fig = px.histogram(df, x="total_bill", y="tip", histfunc='avg')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **BOX plot**
#
# Using Seaborn Library

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Boxplots are a standardized way of displaying the distribution of data based on a five number summary (“minimum”, first quartile (Q1), median, third quartile (Q3), and “maximum”).
#
# * median (Q2/50th Percentile): the middle value of the dataset.
# * first quartile (Q1/25th Percentile): the middle number between the smallest number (not the “minimum”) and the median of the dataset.
# * third quartile (Q3/75th Percentile): the middle value between the median and the highest value (not the “maximum”) of the dataset.
# * interquartile range (IQR): 25th to the 75th percentile.
# * whiskers (shown in blue)
# * outliers (shown as green circles)
# * “maximum”: Q3 + 1.5*IQR
# * “minimum”: Q1 -1.5*IQR
#
# ![image.png](data:image/png;base64,...)

# %%
# box plot if you have only one numerical variable
import seaborn as sns

df = sns.load_dataset('iris')
 
# Make boxplot for one group only
sns.boxplot( y=df["sepal_length"] )
#sns.plt.show()
# Out:
# <AxesSubplot:ylabel='sepal_length'>

# %%
#One numerical variable, and several groups
#Let’s say we want to study the distribution of a numerical variable, but for each group separately. Here we study the sepal length of 3 species of flower.

sns.boxplot( x=df["species"], y=df["sepal_length"] )
#ns.plt.show()
# Out:
# <AxesSubplot:xlabel='species', ylabel='sepal_length'>

# %%
# the distribution of several numerical variables, let’s say sepal length and width:
t = sns.load_dataset("tips")
sns.boxplot(x="day", y="total_bill", hue="smoker", data=t)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(x="day", y="total_bill", hue="time", data=t, linewidth=3.5)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(x="time", y="tip", data=t,order=["Dinner", "Lunch"])
# Out:
# <AxesSubplot:xlabel='time', ylabel='tip'>

# %%
# horizonatal
sns.boxplot(y="time", x="tip", data=t, order=["Dinner", "Lunch"])
# Out:
# <AxesSubplot:xlabel='tip', ylabel='time'>

# %%
# or alternatly
sns.boxplot(data=df, orient="h", palette="Set3")
# Out:
# <AxesSubplot:>

# %% [markdown]
# Using Matplotlib

# %%
import seaborn as sns
df = sns.load_dataset("iris")
df.boxplot('sepal_width')
# Out:
# <AxesSubplot:>

# %%
#more than one column
df.boxplot(column=['sepal_width','sepal_length'])
# Out:
# <AxesSubplot:>

# %%
#with notch
df.boxplot(column=['sepal_width'],notch=True)
# Out:
# <AxesSubplot:>

# %%
 #lets make it horizonatal
 df.boxplot(column=['sepal_width'],notch=True,vert=False)
# Out:
# <AxesSubplot:>
